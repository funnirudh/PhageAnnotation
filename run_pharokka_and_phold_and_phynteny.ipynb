# %% [markdown]
# #Pharokka + Phold + Phynteny
#
# [pharokka](https://github.com/gbouras13/pharokka) is a rapid standardised annotation tool for bacteriophage genomes and metagenomes. You can read more about pharokka in the [documentation](https://pharokka.readthedocs.io/).
#
# [phold](https://github.com/gbouras13/phold) is a sensitive annotation tool for bacteriophage genomes and metagenomes using protein structural homology. You can read more about phold in the [documentation](https://phold.readthedocs.io/).
#
# phold uses the [ProstT5](https://github.com/mheinzinger/ProstT5) protein language model to translate protein amino acid sequences to the 3Di token alphabet used by [Foldseek](https://github.com/steineggerlab/foldseek). Foldseek is then used to search these against a database of 803k protein structures mostly predicted using [Colabfold](https://github.com/sokrypton/ColabFold).
#
# [phyntney](https://github.com/susiegriggo/Phynteny_transformer) uses phage synteny (the conserved gene order across phages) with a hybrid transformer/LSTM architecture to assign hypothetical phage proteins to a PHROG category.
#
# The tools are best run sequentially, as Pharokka conducts extra annotation steps like tRNA, tmRNA, CRISPR and INPHARED searches that Phold lacks (for now at least). Pharokka will also (rarely) annotate CDS that Phold can miss. Phynteny can then help annotate remaining hypothetical proteins with a PHROG category.
#
# * **Before you start, please make sure you change the runtime to T4 GPU (or any other kind of GPU if you have $$$), otherwise Phold won't be installed properly**
# * To do this, go to the top toolbar, then to Runtime -> Change runtime type -> Hardware accelerator
#
# * To run the cells, press the play button on the left side
# * Cells 1, 2 and 3 install pharokka, phold and phyntney and download the databases/models.
# * Once they have been run, you can re-run Cell 4 (to run Pharokka), Cell 5 (to run Phold) and Cell 6 (to run Phynteny) as many times as you would like

# %%
#@title 1. Install miniforge

#@markdown This cell installs miniforge

# %%bash

set -e

PYTHON_VERSION=$(python3 -c "import sys; print(f'{sys.version_info.major}.{sys.version_info.minor}')")

echo "python version ${PYTHON_VERSION}"

if [ ! -f CONDA_READY ]; then
  echo "installing miniforge"

  # miniforge 25.9.1 introduces some issue - latest as of 7 Nov 2025 - see https://github.com/gbouras13/phold/issues/106
  # issue is fixed if you use the previous release (25.3.1)
  #wget -qnc https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-Linux-x86_64.sh
  wget -qnc https://github.com/conda-forge/miniforge/releases/download/25.3.1-0/Miniforge3-25.3.1-0-Linux-x86_64.sh
  bash Miniforge3-25.3.1-0-Linux-x86_64.sh -bfp /usr/local 2>&1 1>/dev/null
  conda config --set auto_update_conda false
  touch CONDA_READY
fi

pip install --upgrade matplotlib matplotlib-inline
# Out:
# python version 3.12
# installing miniforge
# warning  libmamba [python-3.12.11-h9e4cc4f_0_cpython] The following files were already present in the environment:
#     - bin/python
# warning  libmamba [charset-normalizer-3.4.2-pyhd8ed1ab_0] The following files were already present in the environment:
#     - bin/normalizer
# warning  libmamba [distro-1.9.0-pyhd8ed1ab_1] The following files were already present in the environment:
#     - bin/distro
# warning  libmamba [jsonpointer-3.0.0-py312h7900ff3_1] The following files were already present in the environment:
#     - bin/jsonpointer
# warning  libmamba [wheel-0.45.1-pyhd8ed1ab_1] The following files were already present in the environment:
#     - bin/wheel
# warning  libmamba [jsonpatch-1.33-pyhd8ed1ab_1] The following files were already present in the environment:
#     - bin/jsondiff
#     - bin/jsonpatch
# warning  libmamba [pip-25.1.1-pyh8b19718_0] The following files were already present in the environment:
#     - bin/pip
#     - bin/pip3
# warning  libmamba [tqdm-4.67.1-pyhd8ed1ab_1] The following files were already present in the environment:
#     - bin/tqdm
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting matplotlib-inline
#   Downloading matplotlib_inline-0.2.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Collecting numpy>=1.23 (from matplotlib)
#   Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting python-dateutil>=2.7 (from matplotlib)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting traitlets (from matplotlib-inline)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 157.6 MB/s eta 0:00:00
# Downloading matplotlib_inline-0.2.1-py3-none-any.whl (9.5 kB)
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 168.9 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 83.2 MB/s eta 0:00:00
# Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 171.6 MB/s eta 0:00:00
# Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 163.8 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Installing collected packages: traitlets, six, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, python-dateutil, matplotlib-inline, contourpy, matplotlib
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 matplotlib-inline-0.2.1 numpy-2.4.4 pillow-12.2.0 pyparsing-3.3.2 python-dateutil-2.9.0.post0 six-1.17.0 traitlets-5.14.3

# %%
#@title 2. Install pharokka and phold and phynteny

#@markdown This cell installs pharokka and phold. It will take a few minutes. Please be patient

PHAROKKA_VERSION="1.9.1"
PHOLD_VERSION="1.2.2"
PHYNTENY_VERSION="0.1.3"

# add paths
import sys
sys.path.append("/usr/local/bin")

# Update environment variables for shell usage
import os
os.environ["PATH"] = "/usr/local/bin:" + os.environ["PATH"]

# create envs
# pharokka isn't compatible with Python 3.13 (Google Colab default)
# so it needs a separate env
from pathlib import Path
flag_file = Path("PHAROKKA_PHOLD_PHYNTENY_READY")
if not flag_file.exists():
  # !conda install -y -c bioconda phold=={PHOLD_VERSION} pharokka=={PHAROKKA_VERSION} pytorch=*=cuda* phynteny_transformer=={PHYNTENY_VERSION}
  # Touch the flag file
  flag_file.touch()
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  54% 0.5398556683473436/1 [00:47<00:02,  5.27s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  76% 0.7571296752670269/1 [00:47<00:01,  6.15s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  57% 0.5693553506385917/1 [00:47<00:02,  5.34s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  69% 0.6943979230529486/1 [00:47<00:01,  5.79s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  56% 0.5625836834193101/1 [00:47<00:02,  5.04s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  78% 0.7792673787227651/1 [00:47<00:01,  5.59s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  59% 0.5895144778802826/1 [00:47<00:02,  5.47s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  72% 0.7198928450238532/1 [00:47<00:01,  5.16s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  59% 0.5862260439252063/1 [00:47<00:02,  4.84s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  62% 0.6161133263241804/1 [00:47<00:01,  5.02s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  80% 0.7974627514261116/1 [00:47<00:01,  6.43s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  62% 0.6150932354821294/1 [00:47<00:01,  4.41s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  74% 0.7398453926532569/1 [00:47<00:01,  5.74s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  64% 0.636832429322585/1 [00:47<00:01,  5.19s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  82% 0.8202069673052945/1 [00:47<00:01,  5.81s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  64% 0.6384743544354743/1 [00:47<00:01,  4.46s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  76% 0.7579504821688268/1 [00:47<00:01,  6.17s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  67% 0.6652511989758022/1 [00:47<00:01,  4.67s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  84% 0.8397164502594382/1 [00:47<00:00,  5.63s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  66% 0.6614636110599922/1 [00:47<00:01,  4.91s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  78% 0.7830759125169647/1 [00:47<00:01,  5.47s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  69% 0.6879302171227045/1 [00:47<00:01,  4.70s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  86% 0.8580129083666922/1 [00:47<00:00,  5.94s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  69% 0.6877183870914018/1 [00:47<00:01,  4.64s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :
14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  70% 0.7029034495749277/1 [00:54<00:01,  5.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  62% 0.62469104092911/1 [00:54<00:01,  4.85s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  93% 0.9347220783509522/1 [00:54<00:00,  3.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :  76% 0.7635491175095175/1 [00:54<00:02,  9.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  75% 0.7487984280158868/1 [00:54<00:01,  4.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  92% 0.9245548204281137/1 [00:54<00:00,  6.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  68% 0.6812815608414697/1 [00:54<00:01,  3.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :  86% 0.8604887390115096/1 [00:54<00:00,  6.52s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  80% 0.8017962007393753/1 [00:54<00:00,  3.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  73% 0.7322618136935526/1 [00:54<00:00,  3.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :  97% 0.9664042513933156/1 [00:54<00:00,  4.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  85% 0.8501498387396715/1 [00:54<00:00,  3.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  79% 0.7856813130935819/1 [00:54<00:00,  2.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  91% 0.9058794554179791/1 [00:54<00:00,  2.76s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  83% 0.8317830728497716/1 [00:54<00:00,  2.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  96% 0.9553258310002029/1 [00:54<00:00,  2.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  88% 0.876665209331988/1 [00:54<00:00,  2.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  93% 0.9317921813155798/1 [00:54<00:00,  2.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  98% 0.976918242452591/1 [00:55<00:00,  2.50s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | : 100% 1.0/1 [00:55<00:00,  6.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :   0% 0.0006585779700202317/1 [00:55<23:17:40, 83916.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | : 100% 1.0/1 [00:55<00:00,  4.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  14% 0.14027710761430934/1 [00:55<03:58, 276.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  28% 0.2766027474084973/1 [00:55<01:24, 116.32s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  41% 0.40502545156244246/1 [00:55<00:39, 65.88s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | : 100% 1.0/1 [00:55<00:00,  9.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | : 100% 1.0/1 [00:55<00:00,  9.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  51% 0.5064464589455582/1 [00:55<00:21, 44.44s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  66% 0.6552850801701305/1 [00:55<00:09, 26.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  82% 0.8192709947051682/1 [00:55<00:02, 16.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  95% 0.949669432769174/1 [00:56<00:00, 11.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | : 100% 1.0/1 [00:56<00:00,  2.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | : 100% 1.0/1 [00:56<00:00,  2.50s/it]
#
#
# libcublas-12.9.1.4   | 446.1 MB  | : 100% 1.0/1 [00:56<00:00, 34.81s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | : 100% 1.0/1 [00:56<00:00, 11.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# libcudnn-9.10.2.21   | 502.4 MB  | : 100% 1.0/1 [01:13<00:00, 13.08s/it]
# libmagma-2.9.0       | 528.8 MB  | : 100% 1.0/1 [01:29<00:00, 14.06s/it]
#
#
#
#
#
# libcusparse-12.5.10. | 199.2 MB  | : 100% 1.0/1 [01:34<00:00,  8.79s/it]
#
#
#
#
# nccl-2.29.7.1        | 281.9 MB  | : 100% 1.0/1 [01:40<00:00, 11.65s/it]
#
#
#
#
#
#
#
# triton-3.4.0         | 180.4 MB  | : 100% 1.0/1 [01:48<00:00,  6.68s/it]
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | : 100% 1.0/1 [01:53<00:00,  8.27s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | : 100% 1.0/1 [01:56<00:00,  4.68s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | : 100% 1.0/1 [02:01<00:00,  4.57s/it]
#
#
#
# foldseek-10.941cd33  | 410.2 MB  | : 100% 1.0/1 [02:23<00:00, 12.34s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | : 100% 1.0/1 [02:24<00:00,  5.19s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | : 100% 1.0/1 [02:28<00:00,  7.41s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | : 100% 1.0/1 [02:28<00:00,  6.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | : 100% 1.0/1 [02:29<00:00,  4.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | : 100% 1.0/1 [02:30<00:00,  9.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | : 100% 1.0/1 [02:32<00:00,  2.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | : 100% 1.0/1 [02:38<00:00,  2.50s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | : 100% 1.0/1 [02:42<00:00, 11.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtorch-2.8.0       | 836.2 MB  | : 100% 1.0/1 [02:54<00:00, 22.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
#@title 3. Download pharokka phold databases

#@markdown This cell downloads the pharokka then the phold database. It will take some time (10-15 minutes probably depending on Zenodo's traffic). Please be patient. Perhaps go for a walk or have a coffee or tea.


# %%time

print("Downloading pharokka database. This will take a few minutes. Please be patient :)")
# !install_databases.py -o pharokka_db


print("Downloading phold database. This will take a few minutes. Please be patient :)")
# !phold install -d phold_db -t 8 --foldseek_gpu


print("Downloading phynteny database. This will take a few minutes. Please be patient :)")
# !install_models -o  phynteny_models
# Out:
# Downloading pharokka database. This will take a few minutes. Please be patient :)
# 2026-04-19 09:57:34.001 | INFO     | databases:instantiate_install:124 - Checking Pharokka database installation in pharokka_db.
# 2026-04-19 09:57:34.001 | INFO     | databases:check_db_installation:252 - PHROGs Database file VERSION_1_8_0 is missing.
# 2026-04-19 09:57:34.001 | INFO     | databases:check_db_installation:259 - VFDB Databases are missing.
# 2026-04-19 09:57:34.001 | INFO     | databases:check_db_installation:266 - CARD Databases are missing.
# 2026-04-19 09:57:34.001 | INFO     | databases:check_db_installation:272 - PHROGs Annotation File is missing.
# 2026-04-19 09:57:34.001 | INFO     | databases:check_db_installation:278 - INPHARED Mash Annotation File is missing.
# 2026-04-19 09:57:34.001 | INFO     | databases:check_db_installation:284 - INPHARED Mash Sketch File is missing.
# 2026-04-19 09:57:34.001 | INFO     | databases:instantiate_install:129 - Some Databases are missing.
# 2026-04-19 09:57:34.001 | INFO     | databases:instantiate_install:134 - Downloading Pharokka Databases from https://zenodo.org/record/17110353/files/pharokka_v1.8.0_databases.tar.gz.
#
# 2026-04-19 10:10:39.014 | INFO     | databases:instantiate_install:145 - Database file download OK: a63c485241b900a11989bd1821bfbb09
# 2026-04-19 10:10:39.014 | INFO     | databases:instantiate_install:151 - Extracting DB tarball: file=pharokka_db/pharokka_v1.8.0_databases.tar.gz, output=pharokka_db
# Downloading phold database. This will take a few minutes. Please be patient :)
# 2026-04-19 10:11:09.190 | INFO     | phold:install:1343 - You have specified the phold_db directory to store the Phold database and ProstT5 model
# 2026-04-19 10:11:09.190 | INFO     | phold:install:1355 - Checking that the Rostlab/ProstT5_fp16 ProstT5 model is available in phold_db
# 2026-04-19 10:11:09.195 | INFO     | phold.features.predict_3Di:get_T5_model:125 - Using device: cpu
# 2026-04-19 10:11:09.195 | INFO     | phold.features.predict_3Di:get_T5_model:131 - Loading T5 from: phold_db/Rostlab/ProstT5_fp16
# 2026-04-19 10:11:09.195 | INFO     | phold.features.predict_3Di:get_T5_model:132 - If phold_db/Rostlab/ProstT5_fp16 is not found, it will be downloaded
# 2026-04-19 10:11:09.196 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/refs/main does not exist.
# 2026-04-19 10:11:09.196 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/2c19eb6e3b583f52d34b903b5978d3d30b6b7682 does not exist.
# 2026-04-19 10:11:09.196 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/60fe6bb247c90b8545d7b73820cd796ce6dcbd59 does not exist.
# 2026-04-19 10:11:09.196 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/6fc7be92c58e238f20a6cdea5a87b123a4ad35e2 does not exist.
# 2026-04-19 10:11:09.196 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/74da7b4afcde53faa570114b530c726135bdfcdb813dec3abfb27f9d44db7324 does not exist.
# 2026-04-19 10:11:09.196 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/b1a9ffcef73280cc57f090ad6446b4116b574b6c75d83ccc32778282f7f00855 does not exist.
# 2026-04-19 10:11:09.196 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/e9322396e6e75ecf8da41a9527e24dfa4eeea505 does not exist.
# 2026-04-19 10:11:09.196 | INFO     | phold.features.predict_3Di:get_T5_model:142 - ProstT5 not found. Downloading ProstT5 from Hugging Face
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-04-19 10:15:54.782 | INFO     | phold.features.predict_3Di:get_T5_model:174 - Rostlab/ProstT5_fp16 loaded
# 2026-04-19 10:15:55.052 | INFO     | phold:install:1366 - ProstT5 model downloaded
# 2026-04-19 10:15:55.052 | INFO     | phold.databases.db:install_database:143 - Checking Phold database installation in phold_db.
# 2026-04-19 10:15:55.052 | WARNING  | phold.databases.db:check_db_installation:430 - Phold Database file phold_db/acrs_plddt_over_70_metadata.tsv is missing
# 2026-04-19 10:15:55.053 | WARNING  | phold.databases.db:check_db_installation:439 - Phold Foldseek-GPU Database file phold_db/all_phold_structures_gpu is missing
# 2026-04-19 10:15:55.053 | INFO     | phold.databases.db:install_database:148 - Some Phold databases files are missing
# 2026-04-19 10:15:55.053 | INFO     | phold.databases.db:install_database:158 - Downloading Phold Search DB 1.36M from https://zenodo.org/records/16741548/files/phold_search_db_v_1_0_0.tar.gz
# 2026-04-19 10:15:55.057 | INFO     | phold.utils.external_tools:run_stream:56 - Started running aria2c --dir phold_db --out phold_search_db_v_1_0_0.tar.gz --max-connection-per-server=8 --allow-overwrite=true https://zenodo.org/records/16741548/files/phold_search_db_v_1_0_0.tar.gz ...
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 140074|OK  |   4.0MiB/s|phold_db/phold_search_db_v_1_0_0.tar.gz
#
# Status Legend:
# (OK):download completed.
# 2026-04-19 10:23:20.187 | INFO     | phold.utils.external_tools:run_stream:73 - Done running aria2c --dir phold_db --out phold_search_db_v_1_0_0.tar.gz --max-connection-per-server=8 --allow-overwrite=true https://zenodo.org/records/16741548/files/phold_search_db_v_1_0_0.tar.gz
# 2026-04-19 10:23:24.508 | INFO     | phold.databases.db:install_database:171 - Phold database file download OK: ddbe0d94b1d94a392cfeb4ec113f4362
# 2026-04-19 10:23:24.508 | INFO     | phold.databases.db:install_database:177 - Extracting Phold database tarball: file=phold_db/phold_search_db_v_1_0_0.tar.gz, output=phold_db
# 2026-04-19 10:23:52.165 | INFO     | phold.databases.db:install_database:189 - Some Phold database files compatible with Foldseek-GPU are missing
# 2026-04-19 10:23:52.166 | INFO     | phold.databases.db:install_database:192 - Creating them
# 2026-04-19 10:23:52.166 | INFO     | phold.utils.external_tools:run:45 - Started running foldseek makepaddedseqdb phold_db/all_phold_structures phold_db/all_phold_structures_gpu ...
# 2026-04-19 10:24:21.393 | INFO     | phold.utils.external_tools:run:47 - Done running foldseek makepaddedseqdb phold_db/all_phold_structures phold_db/all_phold_structures_gpu
# Downloading phynteny database. This will take a few minutes. Please be patient :)
# /usr/local/lib/python3.12/site-packages/src/install_models.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Creating 'models' subdirectory in specified path
# Downloading Phynteny models to: /content/phynteny_models/models
# 2026-04-19 10:24:25.759 | INFO     | src.install_models:instantiate_install:51 - Model installation directory (absolute path): /content/phynteny_models/models
# 2026-04-19 10:24:25.759 | WARNING  | src.install_models:check_db_installation:93 - Phynteny models are missing.
# 2026-04-19 10:24:25.759 | INFO     | src.install_models:instantiate_install:61 - Some models are missing.
# 2026-04-19 10:24:25.759 | INFO     | src.install_models:get_model_zenodo:325 - Models will be installed to: /content/phynteny_models/models
# 2026-04-19 10:24:25.759 | INFO     | src.install_models:get_model_zenodo:331 - Downloading tarball to: /content/phynteny_models
# 2026-04-19 10:24:25.759 | INFO     | src.install_models:get_model_zenodo:341 - Downloading Phynteny Models from https://zenodo.org/records/17336733/files/phynteny_transformer_models_2025-06-03.tar.gz.
# 2026-04-19 10:24:25.760 | DEBUG    | src.install_models:get_model_zenodo:342 - path
# 2026-04-19 10:24:25.760 | DEBUG    | src.install_models:get_model_zenodo:343 - https://zenodo.org/records/17336733/files/phynteny_transformer_models_2025-06-03.tar.gz
# 2026-04-19 10:24:26.397 | INFO     | src.install_models:download:114 - Downloading file, total size: 222.05 MB
# Progress: 100.0% (222.0/222.0 MB)
# 2026-04-19 10:24:47.123 | INFO     | src.install_models:get_model_zenodo:350 - Phynteny Models tarball download OK: 511358aca216d214b5d7ca7a57fe2250
# 2026-04-19 10:24:47.123 | INFO     | src.install_models:get_model_zenodo:357 - Extracting Phynteny Models tarball: file=phynteny_models/phynteny_transformer_models_2025-06-03.tar.gz, output=/content/phynteny_models/models
# 2026-04-19 10:24:47.123 | INFO     | src.install_models:untar:202 - Path checks: {'tarball_exists': True, 'tarball_readable': True, 'tarball_size': 232831570, 'output_exists': True, 'output_writable': True}
# 2026-04-19 10:24:48.596 | INFO     | src.install_models:untar:218 - Tarball inspection: {'status': 'success', 'file_count': 14, 'top_level_dirs': ['phynteny_transformer_models_2025-06-03'], 'sample_files': ['phynteny_transformer_models_2025-06-03', 'phynteny_transformer_models_2025-06-03/all_calibration_models.pkl', 'phynteny_transformer_models_2025-06-03/calibration_models.pkl', 'phynteny_transformer_models_2025-06-03/category_mapping.pkl', 'phynteny_transformer_models_2025-06-03/fold_10transformer.model']}
# 2026-04-19 10:24:48.596 | INFO     | src.install_models:untar:221 - Starting extraction: phynteny_models/phynteny_transformer_models_2025-06-03.tar.gz to phynteny_models/models
# 2026-04-19 10:24:50.107 | INFO     | src.install_models:untar:225 - Found 14 items in tarball
# 2026-04-19 10:24:50.107 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03
# 2026-04-19 10:24:50.108 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/all_calibration_models.pkl
# 2026-04-19 10:24:50.110 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/calibration_models.pkl
# 2026-04-19 10:24:50.111 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/category_mapping.pkl
# 2026-04-19 10:24:50.111 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_10transformer.model
# 2026-04-19 10:24:50.290 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_1transformer.model
# 2026-04-19 10:24:50.533 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_2transformer.model
# 2026-04-19 10:24:50.795 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_3transformer.model
# 2026-04-19 10:24:51.053 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_4transformer.model
# 2026-04-19 10:24:51.349 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_5transformer.model
# 2026-04-19 10:24:51.619 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_6transformer.model
# 2026-04-19 10:24:51.886 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_7transformer.model
# 2026-04-19 10:24:52.159 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_8transformer.model
# 2026-04-19 10:24:52.405 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_9transformer.model
# 2026-04-19 10:24:52.671 | INFO     | src.install_models:untar:241 - Extraction completed
# 2026-04-19 10:24:52.677 | INFO     | src.install_models:untar:248 - Contents of output directory after extraction: ['phynteny_transformer_models_2025-06-03']
# 2026-04-19 10:24:52.677 | INFO     | src.install_models:untar:265 - Found potential model directories: ['phynteny_transformer_models_2025-06-03']
# 2026-04-19 10:24:52.678 | INFO     | src.install_models:untar:282 - Found 13 files to move from phynteny_models/models/phynteny_transformer_models_2025-06-03 to phynteny_models/models
# 2026-04-19 10:24:52.678 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_6transformer.model to phynteny_models/models/fold_6transformer.model
# 2026-04-19 10:24:52.678 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_1transformer.model to phynteny_models/models/fold_1transformer.model
# 2026-04-19 10:24:52.678 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_2transformer.model to phynteny_models/models/fold_2transformer.model
# 2026-04-19 10:24:52.678 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/category_mapping.pkl to phynteny_models/models/category_mapping.pkl
# 2026-04-19 10:24:52.678 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_5transformer.model to phynteny_models/models/fold_5transformer.model
# 2026-04-19 10:24:52.678 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_4transformer.model to phynteny_models/models/fold_4transformer.model
# 2026-04-19 10:24:52.679 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_10transformer.model to phynteny_models/models/fold_10transformer.model
# 2026-04-19 10:24:52.679 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/calibration_models.pkl to phynteny_models/models/calibration_models.pkl
# 2026-04-19 10:24:52.679 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_8transformer.model to phynteny_models/models/fold_8transformer.model
# 2026-04-19 10:24:52.679 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_7transformer.model to phynteny_models/models/fold_7transformer.model
# 2026-04-19 10:24:52.679 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_9transformer.model to phynteny_models/models/fold_9transformer.model
# 2026-04-19 10:24:52.679 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/all_calibration_models.pkl to phynteny_models/models/all_calibration_models.pkl
# 2026-04-19 10:24:52.679 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_3transformer.model to phynteny_models/models/fold_3transformer.model
# 2026-04-19 10:24:52.679 | INFO     | src.install_models:untar:295 - Successfully moved 13 files to phynteny_models/models
# 2026-04-19 10:24:52.679 | INFO     | src.install_models:untar:299 - Removing temporary directory: phynteny_models/models/phynteny_transformer_models_2025-06-03
# 2026-04-19 10:24:52.680 | INFO     | src.install_models:get_model_zenodo:363 - Keeping tarball at phynteny_models/phynteny_transformer_models_2025-06-03.tar.gz
# 2026-04-19 10:24:52.680 | INFO     | src.install_models:get_model_zenodo:367 - Installed 10 model files
# 2026-04-19 10:24:52.680 | INFO     | src.install_models:get_model_zenodo:372 - Done.
# 2026-04-19 10:24:52.680 | INFO     | src.install_models:instantiate_install:63 - Models successfully downloaded to: /content/phynteny_models/models
#
# Installation Summary:
# ---------------------
# Models directory: /content/phynteny_models/models
# Model files installed: 10
# Confidence dictionary: Installed
#
# When running phynteny_transformer, use:
#   phynteny_transformer -m /content/phynteny_models/models [other options] INPUT_FILE
# CPU times: user 5.25 s, sys: 1.37 s, total: 6.62 s
# Wall time: 27min 21s

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#@title 4. Run Pharokka

#@markdown First, upload your phage(s) as a nucleotide input FASTA file

#@markdown Click on the folder icon to the left and use the file upload button.

#@markdown Once it is uploaded, write the file name in the INPUT_FILE field on the right.

#@markdown Then provide a directory for pharokka's output using PHAROKKA_OUT_DIR.
#@markdown The default is 'output_pharokka'.

#@markdown Then type in a gene prediction tool for pharokka.
#@markdown Please choose either 'phanotate', 'prodigal', or 'prodigal-gv'.

#@markdown You can also provide a prefix for your output files with PHAROKKA_PREFIX.
#@markdown If you provide nothing it will default to 'pharokka'.

#@markdown You can also provide a locus tag for your output files.
#@markdown If you provide nothing it will generate a random locus tag.

#@markdown You can click FAST to turn off --fast.
#@markdown By default it is True so that Pharokka runs faster in the Colab environment.

#@markdown You can click META to turn on --meta if you have multiple phages in your input.

#@markdown You can click META_HMM to turn on --meta_hmm.

#@markdown You can click FORCE to overwrite the output directory.
#@markdown This may be useful if your earlier pharokka run has crashed for whatever reason.

#@markdown The results of Pharokka will be in the folder icon on the left hand panel.
#@markdown Additionally, it will be zipped so you can download the whole directory.

#@markdown The file to download is PHAROKKA_OUT_DIR.zip, where PHAROKKA_OUT_DIR is what you provided

#@markdown If you do not see the output directory,
#@markdown refresh the window by either clicking the folder with the refresh icon below "Files"
#@markdown or double click and select "Refresh".


# %%time
import os
import sys
import subprocess
import zipfile
INPUT_FILE = '/content/phiCD508_in_AJ002.fasta' #@param {type:"string"}

if os.path.exists(INPUT_FILE):
    print(f"Input file {INPUT_FILE} exists")
else:
    print(f"Error: File {INPUT_FILE} does not exist")
    print(f"Please check the spelling and that you have uploaded it correctly")
    sys.exit(1)

PHAROKKA_OUT_DIR = 'output_pharokka'  #@param {type:"string"}
GENE_PREDICTOR = 'phanotate'  #@param {type:"string"}
allowed_gene_predictors = ['phanotate', 'prodigal', 'prodigal-gv']
# Check if the input parameter is valid
if GENE_PREDICTOR.lower() not in allowed_gene_predictors:
    raise ValueError("Invalid GENE_PREDICTOR. Please choose from: 'phanotate', 'prodigal', 'prodigal-gv'.")

PHAROKKA_PREFIX = 'pharokka'  #@param {type:"string"}
LOCUS_TAG = 'Default'  #@param {type:"string"}
FAST = True  #@param {type:"boolean"}
META = False  #@param {type:"boolean"}
META_HMM = False  #@param {type:"boolean"}
FORCE = True  #@param {type:"boolean"}


# Construct the command
# need to suppress PYTHONWARNINGS for phanotate version handling
command = (
    f'pharokka.py -d pharokka_db -i {INPUT_FILE} -t 4 '
    f'-o {PHAROKKA_OUT_DIR} -p {PHAROKKA_PREFIX} -l {LOCUS_TAG} -g {GENE_PREDICTOR}'
)

if FORCE is True:
  command = f"{command} -f"

if FAST is True:
  command = f"{command} --fast"

if META is True:
  command = f"{command} -m"

if META_HMM is True:
  command = f"{command} --meta_hmm"

# Execute the command
try:
    print("Running pharokka")
    subprocess.run(command, shell=True, check=True)
    print("pharokka completed successfully.")
    print(f"Your output is in {PHAROKKA_OUT_DIR}.")
    print(f"Zipping the output directory so you can download it all in one go.")

    zip_filename = f"{PHAROKKA_OUT_DIR}.zip"

    # Zip the contents of the output directory
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(PHAROKKA_OUT_DIR):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), PHAROKKA_OUT_DIR))
    print(f"Output directory has been zipped to {zip_filename}")


except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
# Out:
# Input file SAOMS1.fasta exists
# Running pharokka
# pharokka completed successfully.
# Your output is in output_pharokka.
# Zipping the output directory so you can download it all in one go.
# Output directory has been zipped to output_pharokka.zip
# CPU times: user 75.6 ms, sys: 3.47 ms, total: 79.1 ms
# Wall time: 1min 42s

# %%
#@title 5. Run phold

#@markdown This cell will run phold on the output of cell 3's Pharokka run

#@markdown You do not need to provide any further input files

#@markdown You can now provide a directory for phold's output with PHOLD_OUT_DIR.
#@markdown The default is 'output_phold'.

#@markdown You can also provide a prefix for your output files with PHOLD_PREFIX.
#@markdown If you provide nothing it will default to 'phold'.

#@markdown You can click FORCE to overwrite the output directory with .
#@markdown This may be useful if your earlier phold run has crashed for whatever reason.

#@markdown If your input has multiple phages, you can click SEPARATE.
#@markdown This will output separate GenBank files in the output directory.

#@markdown The results of Phold will be in the folder icon on the left hand panel.
#@markdown Additionally, it will be zipped so you can download the whole directory.

#@markdown The file to download is PHOLD_OUT_DIR.zip, where PHOLD_OUT_DIR is what you provided

#@markdown If you do not see the output directory,
#@markdown refresh the window by either clicking the folder with the refresh icon below "Files"
#@markdown or double click and select "Refresh".


# %%time
import os
import subprocess
import zipfile

# phold input is pharokka output
PHOLD_INPUT = f"{PHAROKKA_OUT_DIR}/{PHAROKKA_PREFIX}.gbk"
PHOLD_OUT_DIR = 'output_phold'  #@param {type:"string"}
PHOLD_PREFIX = 'phold'  #@param {type:"string"}
FORCE = True  #@param {type:"boolean"}
SEPARATE = False  #@param {type:"boolean"}

# Construct the command
command = f"phold run -i {PHOLD_INPUT} -t 4 -o {PHOLD_OUT_DIR} -p {PHOLD_PREFIX} -d phold_db --foldseek_gpu"

if FORCE is True:
  command = f"{command} -f"
if SEPARATE is True:
  command = f"{command} --separate"


# Execute the command
try:
    print("Running phold")
    subprocess.run(command, shell=True, check=True)
    print("phold completed successfully.")
    print(f"Your output is in {PHOLD_OUT_DIR}.")
    print(f"Zipping the output directory so you can download it all in one go.")

    zip_filename = f"{PHOLD_OUT_DIR}.zip"

    # Zip the contents of the output directory
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(PHOLD_OUT_DIR):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), PHOLD_OUT_DIR))
    print(f"Output directory has been zipped to {zip_filename}")


except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")

# %%
#@title 6. Run Phynteny

#@markdown This cell will run phynteny on the output of cell 5's Phold run to predict the function of remaining hypothetical proteins

#@markdown You do not need to provide any further input files

#@markdown You can now provide a directory for phynteny's output with PHYNTENY_OUT_DIR.
#@markdown The default is 'output_phynteny'.

#@markdown You can click FORCE to overwrite the output directory with .
#@markdown This may be useful if your phynteny run has crashed for whatever reason.

#@markdown The results of Phynteny will be in the folder icon on the left hand panel.
#@markdown Additionally, it will be zipped so you can download the whole directory.

#@markdown The file to download is PHYNTENY_OUT_DIR.zip, where PHYNTENY_OUT_DIR is what you provided

#@markdown If you do not see the output directory,
#@markdown refresh the window by either clicking the folder with the refresh icon below "Files"
#@markdown or double click and select "Refresh".


# %%time
import os
import subprocess
import zipfile

# phynteny input is pharokka output
PHYNTENY_INPUT = f"{PHOLD_OUT_DIR}/{PHOLD_PREFIX}.gbk"
PHYNTENY_OUT_DIR = 'output_phynteny'  #@param {type:"string"}
FORCE = False  #@param {type:"boolean"}

# Construct the command
command = f"phynteny_transformer -m  /content/phynteny_models/models -o {PHYNTENY_OUT_DIR} {PHYNTENY_INPUT}"
if FORCE is True:
  command = f"{command} -f"


# Execute the command
try:
    print("Running phynteny")
    subprocess.run(command, shell=True, check=True)
    print("phynteny completed successfully.")
    print(f"Your output is in {PHYNTENY_OUT_DIR}.")
    print(f"Zipping the output directory so you can download it all in one go.")

    zip_filename = f"{PHYNTENY_OUT_DIR}.zip"

    # Zip the contents of the output directory
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(PHYNTENY_OUT_DIR):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), PHYNTENY_OUT_DIR))
    print(f"Output directory has been zipped to {zip_filename}")


except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
